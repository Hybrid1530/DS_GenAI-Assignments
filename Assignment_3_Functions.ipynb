# %% [markdown]
# #Theory Questions

# %% [markdown]
# **1. What is the difference between a function and a method in Python?**
#
# ->*Function:*
# 1.   It is a bock of code that is defined to perform specific task.
# 2.   "def" keyword is used to define a function.
#
#       Ex. def sum(): //Sum is the name of the function
#
#       calc=1+2+3+4  //arguments
#
#       return calc  //this function will return the value of calc.
#
# Method:
# 1.  A function that is associated with an object.
# 2. it is called using the dot "." operator.
#
# Ex. name="dev" //Here name is a object
#
# print(name.capitalize()) //"capitalize function is a method it will make the 1st alphabet of the string capital."

# %% [markdown]
# **2.Explain the concept of function arguments and parameters in Python ?**
#
# ->
# 1.  Parameters are the variables  we assign in a function definition.
# 2.   Arguments are the values we pass to the function while calling it.
#
# Ex.def add(a, b):  // a and b are parameters
#
#   return a + b
#
#   result = add(5, 3)  // 5 and 3 are arguments

# %% [markdown]
# **3. What are the different ways to define and call a function in Python ?**
#
# -> There are two different ways to define and call functions,
#
# 1.   using "def"
#
#       *     Ex. def sum():
#       sum=3+2
#       return sum
#
#       print(sum())
#       *   in the above example we can directly define a function and give valuesby arguments inside the function.
#       *   Ex. def sum(a,b):
#       sum=a+b
#       return sum
#
#       print(sum(3+5))
#       *   in this example we are calling this function by passing values in it.
#
#
# 2.   using "lambda"
#     * keyword lambda is used.
#
#     *  square = lambda x: x * x
#
#       print(square(2))
#     *   in lambda no return statement is required.

# %% [markdown]
# **4. What is the purpose of the `return` statement in a Python function?**
#
# -> The "return" statement , return back the final value to the function call after executing the block of code.
#
#   Ex. def ttl(a,b):
#
#   c=a+b
#
#   return c
#
# return_value=ttl(5,5) // output will be 10
#
# Here the return_value will be assigned with value 10

# %% [markdown]
# **5. What are iterators in Python and how do they differ from iterables?**
#
# ->An iterator is an object that allows traversal through a countable number of values.
#
#  Iterables can be defined as objects on which an iterator iterates.
#
# 1.It is used to iterate over iterable objects like lists, tuples, sets, etc
#
# 2.iter() function is used to create an iterator containing an iterable object.
#
# a=[1,2,3,4]
#
# b=iter(a)
#
# print(next(b)) // 1 is printed
#
# print(next(b)) // 2 is printed
#
# print(next(b)) // 3 is printed

# %% [markdown]
# **6. Explain the concept of generators in Python and how they are defined ?**
#
# ->1.Generators are a simple way to create iterators using functions and the yield keyword instead of returning values.
#
# 2.Unlike the return statement, which exits the function, yield returns a value and pauses the function’s state, allowing it to resume from where it left off.
#
# 3.SYNTAX:
#
# def counter(n): // similar like a regular function
#
#   for i in range(n):  // passng arguments like a regular function
#
#   yield i+1 // instead of return we use yield
#
# a=counter(5)
# for i in range(5)
#
# print(next(a))  // it produce one output value at time.

# %% [markdown]
# **7. What are the advantages of using generators over regular functions?**
#
# -> 1. generator function yields the value one at a time which can be great while debugging or if the user want values once a time.
#
#   2.regular function returns the final value of a function.
#
#   3.Generators do not store the entire sequence in memory, making them suitable for large datasets or infinite sequences.
#
#   4. def count_up_to(n):
#     for i in range(n):
#         yield i
#
# so now if we call the above function  it will produce only one out put at a time . we have to use next() funtion to get the values.

# %% [markdown]
# **8.What is a lambda function in Python and when is it typically used?**
#
# ->1.Lambda functions are small, anonymous functions defined using the lambda keyword.
#
# 2.They are used for creating small, throwaway functions without the need to formally define a function using def
#
# SYNTAX:
#
# a=lambda x: x**2
#
# print(a(2)) // 4 will be th output

# %% [markdown]
# **9.Explain the purpose and usage of the `map()` function in Python.**
#
# ->1.The map function applies a given function to all items in an input iterable (like a list) and returns an iterator with the results.
#
#  2.Used to transform each item in an iterable by applying the specified function.
#
#  ex:
#
#  a=[1,2,3,4,5]
#
#  print(list(map((lambda x: x**2),a))) // this will return a list with square of all the elements in list a.

# %% [markdown]
# **10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?**
#
# ->
# 1.   Map():
#
#     * The map function applies a given function to all items in an iterable (like a list).
#     *   returns an iterator with the results.
#     * Ex.
#     num = [1, 2, 3, 4]
#
#       s = map(lambda x: x**2, num)
#
#       print(list(s))  # [1, 4, 9, 16]
#
#
# 2.  reduce()
#
#     *  The reduce function from the functools module applies a given function cumulatively to the items of a sequence.
#     *   from left to right, to reduce the sequence to a single value.
#     *   Ex:
#
#       from functools import reduce
#
#       nums = [1, 2, 3, 4, 5]
#
#       total = reduce(lambda x, y: x + y, nums)
#
#       print(total)  # 15
#
# 2.  filter()
#
#     *  The filter function constructs an iterator from elements of an iterable for which a specified function returns True.
#
#     *   Used for filtering elements from an iterable based on a condition defined by the function.
#     *   Ex:
#
#       nums = [1, 2, 3, 4, 5]
#
#       even = filter(lambda x: x % 2 == 0, nums)
#
#       print(list(even))  // [2, 4]

# %% [markdown]
# **11.Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list:**
#
# **[47,11,42,13] **
# ![a3_11.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Practical Questions

# %%
 #1.Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

def list_input(a):
  sum=0
  l1=[]
  for i in a:
    if type(i)== int or type(i)==float:
      if i%2==0:
        sum=sum+i
    else:
      continue
  l1.append(sum)
  return l1

list_input([1,2,3,4,5,5.5,2.0,"a"])
# Out:
# [8.0]

# %%
# 2.Create a Python function that accepts a string and returns the reverse of that string.

def reverse_str(a):
  print("Reverse of the string is",a[::-1])

reverse_str(input("Enter the string:"))
# Out:
# Enter the string:Devang
# Reverse of the string is gnaveD

# %%
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.

def sq_num(a):
  l1=[]
  for i in a:
    if type(i)== int:
      i=i**2
      l1.append(i)
    else:
      l1.append("Non integer type")
      continue
  return l1
sq_num([1,2,3,4,5]) #only accepts integer value and for non integer it will print "Non integer type"
# Out:
# [1, 4, 9, 16, 25]

# %%
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

def prime_num(a):
    if a<1 or a>200:
      print("Enter with in the range")
    else:
      if a <= 1:
          return False
      for i in range(2, a):
          if a % i == 0:
              return False
      return True

print("Prime Number Checker !")
prime_num(int(input("Enter the number between 1 to 200 :")))
# Out:
# Prime Number Checker !
# Enter the number between 1 to 200 :7
# True

# %%
# 5.Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.

class Fib_Iterator:
    def __init__(self, total_terms):
        self.total_terms = total_terms
        self.generated = 0
        self.first = 0
        self.second = 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.generated >= self.total_terms:
            raise StopIteration
        if self.generated == 0:
            self.generated += 1
            return self.first
        elif self.generated == 1:
            self.generated += 1
            return self.second
        else:
            next_value = self.first + self.second
            self.first, self.second = self.second, next_value
            self.generated += 1
            return next_value

# Example usage
fib_sequence = Fib_Iterator(5)
for number in fib_sequence:
    print(number)
# Out:
# 0
# 1
# 1
# 2
# 3

# %%
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

def power(ip_exponent):
    for i in range(ip_exponent + 1):
        yield 2 ** i

e=power(5)
for i in range(5):
  print(next(e))
# Out:
# 1
# 2
# 4
# 8
# 16

# %%
# 7. Implement a generator function that reads a file line by line and yields each line as a string.
from google.colab import files

uploaded = files.upload()

def read_file_line_by_line(filename):
    with open(filename, 'r') as file:
        for line in file:
            yield line.rstrip('\n')  # Removes the newline character

for line in read_file_line_by_line('a3_f_check.txt'):
    print(line)
# Out:
#      <input type="file" id="files-92653fc4-0297-49b9-906a-e06fe3d86da2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92653fc4-0297-49b9-906a-e06fe3d86da2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#  8.Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

l1=[(1,3),(1,1),(1,5),(1,2),(1,4)]

s = sorted(l1, key=lambda x: x[1])

print(s)
# Out:
# [(1, 1), (1, 2), (1, 3), (1, 4), (1, 5)]

# %%
# 9.Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit
c1=[10,20,30,40,55]

def cel_far(celsius):
  Fahrenheit = (celsius * (9/5)) + 32
  return Fahrenheit

list(map(cel_far,c1))
# Out:
# [50.0, 68.0, 86.0, 104.0, 131.0]

# %%
#  10.Create a Python program that uses filter() to remove all the vowels from a given string.
vowels = "aeiouAEIOU"
string = input("Enter the string: ")

result = filter(lambda x: x not in vowels, string)

without_vowels = ''.join(result)

print("With Vowels:", string)
print("Without Vowels:", without_vowels)
# Out:
# Enter the string: Devang
# With Vowels: Devang
# Without Vowels: Dvng

# %%
'''11.Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:

Order Number    Book Title and Author               Quantity          Price per Item
34587           Learning Python, Mark Lutz              4                   40.95
98762           Programming Python, Mark Lutz           5                   56.80
77226           Head First Python, Paul Barry           3                   32.95
88112           Einführung in Python3, Bernd Klein      3                   24.99


Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
order is smaller than 100,00 €.

Write a Python program using lambda and map.'''

orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

result = list(map(lambda order: (order[0],round(order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0), 2)), orders))
print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85), (88112, 84.97)]
